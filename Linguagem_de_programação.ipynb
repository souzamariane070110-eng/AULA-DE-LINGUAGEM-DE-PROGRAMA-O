# %% [markdown]
# <a href="https://colab.research.google.com/github/souzamariane070110-eng/AULA-DE-LINGUAGEM-DE-PROGRAMA-O/blob/main/Linguagem_de_programa%C3%A7%C3%A3o.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##U1_A1

# %%
##Nosso primeiro programa

# %%
print("Hello word")
# Out:
# Hello word

# %%
##2 criando variaveis de tipos diferentes
x = 10
nome = 'Anderson'
nota = 8.75
fez_inscricao = True

# %%
print(x)
print(nome)
print(nota)
print(fez_inscricao)
# Out:
# 10
# Anderson
# 8.75
# True

# %%
print(type(x))
print(type(nome))
print(type(nota))
print(type(fez_inscricao))
# Out:
# <class 'int'>
# <class 'str'>
# <class 'float'>
# <class 'bool'>

# %%
nome = input("digite seu nome:")
# Out:
# digite seu nome:

# %%
print(f"Olá {nome}, bem vindo à disciplina de programação")
# Out:
# Olá , bem vindo à disciplina de programação

# %%
Nota_1 = int(input("Digite a nota "))
Nota_2 = int(input("Digite a nota "))
Nota_3 = int(input("Digite a nota "))
Nota_4 = int(input("Digite a nota "))
# Out:
# Digite a nota
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_776/2895570229.py in <cell line: 0>()
# ----> 1 Nota_1 = int(input("Digite a nota "))
#       2 Nota_2 = int(input("Digite a nota "))
#       3 Nota_3 = int(input("Digite a nota "))
#       4 Nota_4 = int(input("Digite a nota "))
#
# ValueError: invalid literal for int() with base 10: ''

# %%
media = (Nota_1+Nota_2+Nota_3+Nota_4)/4

# %%
print(media)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_776/536332280.py in <cell line: 0>()
# ----> 1 print(media)
#
# NameError: name 'media' is not defined

# %%
if media >= 6:
  situação = "Aprovado"
else:
  situação = "Reprovado"
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_776/2852462986.py in <cell line: 0>()
# ----> 1 if media >= 6:
#       2   situação = "Aprovado"
#       3 else:
#       4   situação = "Reprovado"
#
# NameError: name 'media' is not defined

# %%
print(situação)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_776/3422732775.py in <cell line: 0>()
# ----> 1 print(situação)
#
# NameError: name 'situação' is not defined

# %% [markdown]
# ##U1_A2

# %%
print(10>5)
# Out:
# True

# %%
print(5>10)
# Out:
# False

# %%
print(7==7)
# Out:
# True

# %%
#guardando informações
idade = 15
e_maior_de_idade = idade >=18
print(e_maior_de_idade)
# Out:
# False

# %%
print(True and True)
# Out:
# True

# %%
print(True or False)
# Out:
# True

# %%
print(True and False)
# Out:
# False

# %%
idade = int(input("Digite sua idade  "))
if idade < 18:
  print("Menor de idade")
elif idade >= 18 and idade <65:
  print("Adulto")
else:
  print("Idoso")
# Out:
# Digite sua idade
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_776/3446121667.py in <cell line: 0>()
# ----> 1 idade = int(input("Digite sua idade  "))
#       2 if idade < 18:
#       3   print("Menor de idade")
#       4 elif idade >= 18 and idade <65:
#       5   print("Adulto")
#
# ValueError: invalid literal for int() with base 10: ''

# %%
idade = int(input("Digire sua idade: "))
if idade < 12:
  print("Recomendamos o filme infantil 1")
elif idade >= 12 and idade <18:
  print("Recomendamos o filme infantil 2")
else:
  print("Recomendamos o filme infantil 3")

# %%
quantidade_de_ingresso = 10
if quantidade_de_ingresso > 0:
  print("ingressos disponiveis, Divirta-se no cinema")
else:
  print("Desculpe, todos os ingressos foram vendidos")
# Out:
# ingressos disponiveis, Divirta-se no cinema

# %%
#Exercicio deixado pelo professor

# %%
idade = int(input("Digite sua idade: "))
if idade <= 12:
  filme = "Filme infantil 1"
  quantidade_de_ingresso = 10
elif idade <18:
  filme = "Filme infantil 2"
  quantidade_de_ingresso = 5
else:
  filme = "Filme infantil 3"
  quantidade_de_ingresso = 0

print(f"\nRecomendamos o {filme}.")

if quantidade_de_ingresso >0:
  print("Ingressos disponiveis! Divirtasse no cinema.")
else:
  print("Desculpe, todos os ingressos foram vendidos.")
# Out:
# Digite sua idade:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_776/1073223986.py in <cell line: 0>()
# ----> 1 idade = int(input("Digite sua idade: "))
#       2 if idade <= 12:
#       3   filme = "Filme infantil 1"
#       4   quantidade_de_ingresso = 10
#       5 elif idade <18:
#
# ValueError: invalid literal for int() with base 10: ''

# %% [markdown]
# ##U1_A3

# %%
numeros = [1,2,3,4,5]

for numeros in numeros:
  print(numeros)
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
print(type(numeros))
# Out:
# <class 'int'>

# %%
numero = int(input("Digite um número(ou 0 para sair): "))

while numero !=0:
  if numero % 2 == 0:
    print("O numero é par. ")
  else:
    print("O numero é impar.")

numero = int(input("Digite um numero número(ou 0 para sair):"))
# Out:
# Digite um número(ou 0 para sair):
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_776/899449731.py in <cell line: 0>()
# ----> 1 numero = int(input("Digite um número(ou 0 para sair): "))
#       2
#       3 while numero !=0:
#       4   if numero % 2 == 0:
#       5     print("O numero é par. ")
#
# ValueError: invalid literal for int() with base 10: ''

# %%
for x in range(1,15):
  print (x)

# %%
filmes = ["1","2","3","4","5"]
print("Bem vindo a classificação do filme")
print("Você tem cinco filmes para classificar")
print("Digite '0' a qualquer momento para parar. \n")

for filme in filmes:
  classificacao = input(f"Como voce classifica '{filmes}' de 1 a 5 (ou 0 para parar): ")

  if classificacao == '0':
    print ("QUE PENA")
    break

  classificacao = int(classificacao)
  if classificacao <1 or classificacao >5:
    print("nota invalida")
  else:
    print(f"voce classificou '{filmes}' com a  '{classificacao}' entrelas.\n")
  print("obrigado")
# Out:
# Bem vindo a classificação do filme
# Você tem cinco filmes para classificar
# Digite '0' a qualquer momento para parar.
#
# Como voce classifica '['1', '2', '3', '4', '5']' de 1 a 5 (ou 0 para parar):
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_776/1149136446.py in <cell line: 0>()
#      11     break
#      12
# ---> 13   classificacao = int(classificacao)
#      14   if classificacao <1 or classificacao >5:
#      15     print("nota invalida")
#
# ValueError: invalid literal for int() with base 10: ''

# %% [markdown]
# ##U1_A4

# %%
numero = [1,2,3,4,5]

comprimento = len(numero)

print(comprimento)
# Out:
# 5

# %%
range(5)
# Out:
# range(0, 5)

# %%
def soma(a,b):
  resultado = a + b
  return resultado

# %%
resultado_soma = soma(5,6)

# %%
print(resultado_soma)
# Out:
# 11

# %%
def e_par(numero):
  if numero % 2 == 0:
    return True
  else:
    return False

# %%
numero = 5
teste = e_par(numero)

# %%
print (teste)
# Out:
# False

# %%
media = 8.85462325458
arredondar_media = lambda media1: round(media,2)

# %%
media_arredondada = arredondar_media(media)
print(media_arredondada)
# Out:
# 8.85

# %%
media
# Out:
# 8.85462325458

# %% [markdown]
# ##encerramento

# %%
#Funções definidas pelo usuario
def calcular_desconto(valor, percentual):
  """Calcula o valor final aplicando um desconto percentual."""
  if percentual < 0 or percentual >100:
    return None #marcação invalida
  desconto = valor * (percentual/100)
  return valor - desconto
def registrar_venda(produto, valor_final):
  """imprime o registro de uma venda"""
  print(f">> Venda registrada:{produto} por R${valor_final:.2f}")

#função lambda para arredondar

arredondar = lambda v: round(v,2)

# %%
#variaveis principais do PDV
total_vendas = 0
qts_vendas = 0

# %%
#loop principal do caixa. MINHALOJAPDV
while True:
  print("\n ------ minha loja - pdv ------")
  print("1 - Registrar venda")
  print("2 - Ver relatório do dia")
  print("3 - Encerrar caixa")

  opcao = input("Escolha uma opção: ") # Added this line to get user input for 'opcao'

  if opcao == "0" or opcao == "3": # Changed to allow '3' for encerrar caixa as well
    print("Encerrando o caixa. Até amanha")
    break

  elif opcao == "1":
    produto = input("Nome do produto: ")
    valor = float(input("Valor do produto: R$ "))
    percentual = float(input("Desconto (%):"))

    valor_final = calcular_desconto(valor, percentual)

    if valor_final is None:
      print("Desconto invalido! Use um valor entre 0 e 100")
    else:
      valor_final = arredondar(valor_final)
      registrar_venda(produto, valor_final)
      total_vendas = total_vendas + valor_final
      qts_vendas = qts_vendas + 1

  elif opcao == "2":
    print(f"\nVendas hoje: {qts_vendas}")
    print(f"Total faturado: R$ {arredondar(total_vendas)}")
  else:
    print("opção invalida. Tente de novo")
# Out:
#  ------ minha loja - pdv ------
# 1 - Registrar venda
# 2 - Ver relatório do dia
# 3 - Encerrar caixa
# Escolha uma opção:
# opção invalida. Tente de novo
#
#  ------ minha loja - pdv ------
# 1 - Registrar venda
# 2 - Ver relatório do dia
# 3 - Encerrar caixa
# Escolha uma opção:
# opção invalida. Tente de novo
#
#  ------ minha loja - pdv ------
# 1 - Registrar venda
# 2 - Ver relatório do dia
# 3 - Encerrar caixa
# Escolha uma opção:
# Escolha uma opção:
# opção invalida. Tente de novo
#
#  ------ minha loja - pdv ------
# 1 - Registrar venda
# 2 - Ver relatório do dia
# 3 - Encerrar caixa
# opção invalida. Tente de novo
#
#  ------ minha loja - pdv ------
# 1 - Registrar venda
# 2 - Ver relatório do dia
# 3 - Encerrar caixa
# Escolha uma opção:
# opção invalida. Tente de novo
#
#  ------ minha loja - pdv ------
# 1 - Registrar venda
# 2 - Ver relatório do dia
# 3 - Encerrar caixa
# Escolha uma opção:
# opção invalida. Tente de novo
#
#  ------ minha loja - pdv ------
# ...

# %% [markdown]
# ##U2_A1

# %%
texto = "Explorando a diversidade de linguagens de programação com python"

# %%
print(f"Tamanho do texto = {len(texto)}")
# Out:
# Tamanho do texto = 64

# %%
print(f"Quantidade de 'e' no texto = {texto.count('e')}")
# Out:
# Quantidade de 'e' no texto = 5

# %%
print(f"As 5 primeiras letras são: {texto[:5]}")
# Out:
# As 5 primeiras letras são: Explo

# %%
cores  = ['v', 'ver', 'az', 'am']

# %%
for cor in cores:
  print(f'Posição = {cores.index(cor)}, cor = {cor}')
# Out:
# Posição = 0, cor = v
# Posição = 1, cor = ver
# Posição = 2, cor = az
# Posição = 3, cor = am

# %%
linguagens = ["python", "java", "c#", "javaScript"]

# %%
print("Antes de listcomp =", linguagens)
# Out:
# Antes de listcomp = ['python', 'java', 'c#', 'javaScript']

# %%
linguagens = [item.lower() for item in linguagens]
print("Depois de listcomp =", linguagens)
# Out:
# Depois de listcomp = ['python', 'java', 'c#', 'javascript']

# %%
vogais = ('a', 'e', 'i', 'o', 'u')

# %%
print(f"Tipo de objeto vogais = {type(vogais)}")
# Out:
# Tipo de objeto vogais = <class 'tuple'>

# %%
for p, z in enumerate(vogais):
  print(f"Posição = {p}, valor = {z}")
# Out:
# Posição = 0, valor = a
# Posição = 1, valor = e
# Posição = 2, valor = i
# Posição = 3, valor = o
# Posição = 4, valor = u

# %%
convidados = ("alice", "rodrigo", "carol", "felipe")
confirmados = ["alice", "rodrigo"]

# %%
print("convidados que ainda nao confirmaram:")
for convidado in convidados:
  if convidado in confirmados:
    continue
  print(convidado)
# Out:
# convidados que ainda nao confirmaram:
# carol
# felipe

# %% [markdown]
# ##U2_A2

# %%
meu_conjunto = set()

# %%
meu_conjunto.add(10)

# %%
meu_conjunto.add(20)
meu_conjunto.add(30)

# %%
meu_conjunto
# Out:
# {10, 20, 30}

# %%
elemento = 20
if elemento in meu_conjunto:
  print(f"{elemento} está no conjunto")
else:
  print(f"{elemento} não está no conjunto")
# Out:
# 20 está no conjunto

# %%
numeros_com_repeticao = [1,2,2,3,3,3,4,4,4,4]

# %%
unicos = set(numeros_com_repeticao)

# %%
numeros_com_repeticao
# Out:
# [1, 2, 2, 3, 3, 3, 4, 4, 4, 4]

# %%
unicos
# Out:
# {1, 2, 3, 4}

# %%
dici_1 = {}

# %%
dici_1['nome'] = "Mariane"
dici_1['idade'] = "18"

# %%
dici_1
# Out:
# {'nome': 'Mariane', 'idade': '18'}

# %%
dici_2 = {'nome': 'Maria', 'idade': '18'}

# %%
dici_2
# Out:
# {'nome': 'Maria', 'idade': '18'}

# %%
dici_3 = dict(nome = 'Maria', idade ='18')

# %%
dici_3
# Out:
# {'nome': 'Maria', 'idade': '18'}

# %%
dici_4 = dict(zip(['nome', 'idade'], ['Maria', '18']))

# %%
dici_4
# Out:
# {'nome': 'Maria', 'idade': '18'}

# %%
#acessando e alterando valores num dicionário
produto = {'nome': 'Notebook', 'preco': 3500.00, 'estoque': 12}

print("Nome:", produto['nome'])
print("Preço", produto['preco'])

produto['estoque'] = 10
produto['categoria'] = 'Informática'

print(produto)
# Out:
# Nome: Notebook
# Preço 3500.0
# {'nome': 'Notebook', 'preco': 3500.0, 'estoque': 10, 'categoria': 'Informática'}

# %%
import numpy as np

my_array = np.array([1,2,3,4,5])
print("array original: ")
print(my_array)
# Out:
# array original:
# [1 2 3 4 5]

# %%
squared_array = my_array ** 2
sum_of_elements = np.sum(my_array)

print("array ao quadrado: ")
print(squared_array)
print("soma dos elementos: ")
print(sum_of_elements)

print("\nElemento no índice 2:", my_array[2])
# Out:
# array ao quadrado:
# [ 1  4  9 16 25]
# soma dos elementos:
# 15
#
# Elemento no índice 2: 3

# %%
import numpy as np

participantes =[
    {"nome": "ketlyn", "localizacao": "EUA", "afiliacao": "Universidade A", "interesses": ["Fisica","Astronomia"]},
    {"nome": "Mariane", "localizacao": "Brasil", "afiliacao": "Universidade B","interesses": ["Biologia","Astronomia"]},
    {"nome": "Carlos", "localizacao": "India", "afiliacao": "Universidade C","interesses": ["Quimica","Engenharia"]},

]

regioes = set(p["localizacao"] for p in participantes)

afiliacoes = {}
for p in participantes:
  aff = p["afiliacao"]
  if aff not in afiliacoes:
    afiliacoes[aff] = []
  afiliacoes[aff].append(p["nome"])

areas = np.array([i for p in participantes for i in p["interesses"]])
unicos, contagem = np.unique(areas, return_counts=True)
mais_popular = unicos[np.argmax(contagem)]

print("Regiões dos participantes:", regioes)
print("Afiliações dos participantes:")
for aff, nomes in afiliacoes.items():
  print(f" {aff}: {', '.join(nomes)}")
print("Área de interesse mais popular:", mais_popular)
# Out:
# Regiões dos participantes: {'India', 'Brasil', 'EUA'}
# Afiliações dos participantes:
#  Universidade A: ketlyn
#  Universidade B: Mariane
#  Universidade C: Carlos
# Área de interesse mais popular: Astronomia

# %% [markdown]
# ##U2_A3

# %%
class Pessoa:
  def __init__(self, nome, idade, genero):
    self.nome = nome
    self.idade = idade
    self.genero = genero
  def cumprimentar(self):
    return f"Olá, meu nome é {self.nome}"

  def aniversario(self):
    self.idade += 1

# %%
pessoa1 = Pessoa ("João", 30, "Masculino")

# %%
print(pessoa1.cumprimentar())
print(f"idade: {pessoa1.idade}")
# Out:
# Olá, meu nome é João
# idade: 30

# %% [markdown]
# ##U2_A4

# %%
import math

print(math.sqrt(25)) # raiz quadrada
print(math.log2(1024)) # logaritimo na base 2
print(math.cos(45)) # cosseno
# Out:
# 5.0
# 10.0
# 0.5253219888177297

# %%
import math as m
print(m.sqrt(25))
print(m.log2(1024))
print(m.cos(45))
# Out:
# 5.0
# 10.0
# 0.5253219888177297

# %%
from math import sqrt, log2, cos

print(sqrt(25))
print(log2(1024))
print(cos(45))
# Out:
# 5.0
# 10.0
# 0.5253219888177297

# %%
import matplotlib.pyplot as plt

x = [1,2,3,4,5]
y = [2,4,1,3,5]

plt.plot(x,y)

plt.xlabel("Eixo X")
plt.ylabel("Eixo Y")
plt.title("Gráfico de Linha")

plt.show()

# %%
import matplotlib.pyplot as plt

meses = ['Janeiro', 'Fevereiro', 'Março', 'Abril', 'Maio']
vendas = [120, 90, 150, 80, 200]

plt.bar(meses, vendas, color='royalblue')

plt.xlabel('Mês')
plt.ylabel('Vendas (em unidades)')
plt.title('Vendas Mensais')

plt.show()

# %% [markdown]
# ##ENCERRAMENTO U2

# %%
import matplotlib.pyplot as plt

# %%
class Produto:
  def __init__(self, nome, preco, categoria, estoque):
    self.nome = nome
    self.preco = preco
    self.categoria = categoria
    self.estoque = estoque

#definimos como o produto aparece quando é impresso
  def __str__(self):
    return (f"{self.nome} | R$ {self.preco:.2f} |"
            f"Categoria: {self.categoria} | Estoque: {self.estoque}")

# %%
catalogo = []
categorias = []

# %%
def adicionar_produto(nome, preco, categoria, estoque):
  novo_produto = Produto(nome, preco, categoria, estoque)
  catalogo.append(novo_produto)
  categorias.append(categoria)
  print(f"Produto '{nome}' adicionado ao catálogo.")

# %%
def listar_catalogo():
  print("\n--- Catálogo da MinhaLoja ---")
  for produto in catalogo:
    print(produto)

# %%
#cadastrar produtos
adicionar_produto("Notebook", 3500.00, "Informática", 12)
adicionar_produto("Smartphone", 2200.00, "Eletrônicos", 18)
adicionar_produto("Cafeteira", 350.00, "Eletrodoméstico", 7)
adicionar_produto("Geladeira", 2900.00, "Eletrodoméstico", 4)
adicionar_produto("Fone Bluetooth", 180.00, "Eletrônicos", 30)

listar_catalogo()
# Out:
# Produto 'Notebook' adicionado ao catálogo.
# Produto 'Smartphone' adicionado ao catálogo.
# Produto 'Cafeteira' adicionado ao catálogo.
# Produto 'Geladeira' adicionado ao catálogo.
# Produto 'Fone Bluetooth' adicionado ao catálogo.
#
# --- Catálogo da MinhaLoja ---
# Notebook | R$ 3500.00 |Categoria: Informática | Estoque: 12
# Smartphone | R$ 2200.00 |Categoria: Eletrônicos | Estoque: 18
# Cafeteira | R$ 350.00 |Categoria: Eletrodoméstico | Estoque: 7
# Geladeira | R$ 2900.00 |Categoria: Eletrodoméstico | Estoque: 4
# Fone Bluetooth | R$ 180.00 |Categoria: Eletrônicos | Estoque: 30

# %%
#grafico por categoria
categorias_unicas = list(set(categorias))
categorias_unicas.sort()

#contagem de produtos em cada categoria (list comprehension)
contagem = [categorias.count(cat) for cat in categorias_unicas]

# %%
plt.bar(categorias_unicas, contagem, color='royalblue')
plt.xlabel("Categoria")
plt.ylabel("Número de Produtos")
plt.title("MinhaLoja - Produtos por Categoria")
# Out:
# Text(0.5, 1.0, 'MinhaLoja - Produtos por Categoria')

# %%
for i, valor in enumerate(contagem):
  plt.text(i, valor, str(valor), ha='center', va='bottom')

plt.grid(axis='y')
plt.show()

# %% [markdown]
# ##U3_A1

# %%
import sqlite3
#1.Conectar ao banco de dados (ou criar um novo)
conn = sqlite3.connect('minhaloja.db')

#2. Criar um objeto cursor
cursor = conn.cursor()

# %%
#3. Definir o comando SQL para criar a tabela
create_table = """
CREATE TABLE IF NOT EXISTS Produtos(
  id INTEGER PRIMARY KEY,
  nome TEXT NOT NULL,
  preco REAL NOT NULL,
  estoque INTEGER
)
"""

# %%
import sqlite3

# Conectar novamente ao banco
conn = sqlite3.connect('minhaloja.db')

# Criar o cursor novamente
cursor = conn.cursor()

# Executar o comando para criar a tabela
cursor.execute(create_table)

# Confirmar as alterações
conn.commit()

print("Tabela Produtos criada com sucesso!")
# Out:
# Tabela Produtos criada com sucesso!

# %%
import sqlite3

# Conectar ao banco de dados
conn = sqlite3.connect('minhaloja.db')

# Criar o cursor
cursor = conn.cursor()

# Dados do novo produto
novo_produto = ('Camiseta', 19.99, 50)

# Comando SQL para inserir o produto
inserir_produto = "INSERT INTO Produtos (nome, preco, estoque) VALUES (?, ?, ?)"

# Executar o comando
cursor.execute(inserir_produto, novo_produto)

# Confirmar a alteração
conn.commit()

print("Produto inserido com sucesso!")
# Out:
# Produto inserido com sucesso!

# %%
import os

# Apagar o banco de dados antigo
if os.path.exists('minhaloja.db'):
    os.remove('minhaloja.db')

print("Banco antigo apagado!")
# Out:
# Banco antigo apagado!

# %%
import sqlite3

conn = sqlite3.connect('minhaloja.db')
cursor = conn.cursor()

# %%
create_table = """
CREATE TABLE IF NOT EXISTS Produtos(
    id INTEGER PRIMARY KEY,
    nome TEXT NOT NULL,
    preco REAL NOT NULL,
    estoque INTEGER
)
"""

cursor.execute(create_table)
conn.commit()

print("Tabela Produtos criada!")
# Out:
# Tabela Produtos criada!

# %%
conn = sqlite3.connect('minhaloja.db')
cursor = conn.cursor()
novo_produto = ('Camiseta', 19.99, 50)

inserir_produto = """
INSERT INTO Produtos (nome, preco, estoque)
VALUES (?, ?, ?)
"""

cursor.execute(inserir_produto, novo_produto)
conn.commit()

print("Produto inserido com sucesso!")
# Out:
# Produto inserido com sucesso!

# %%
conn = sqlite3.connect('minhaloja.db')
cursor = conn.cursor()

cursor.execute("SELECT * FROM Produtos")
produtos = cursor.fetchall()

for produto in produtos:
  print(produto)

conn.close()
# Out:
# (1, 'Camiseta', 19.99, 50)

# %%
import sqlite3

conn = sqlite3.connect('minhaloja.db')
cursor = conn.cursor()

novo_preco = 27.99
produto_id = 2
atualizar_preco = """
UPDATE Produtos
SET preco = ?
WHERE id = ?
"""

cursor.execute(atualizar_preco, (novo_preco, produto_id))
conn.commit()

print("Preço do produto atualizado!")
# Out:
# Preço do produto atualizado!

# %%
import sqlite3

conn = sqlite3.connect('minhaloja.db')
cursor = conn.cursor()

produto_id = 2
cursor.execute("DELETE FROM Produtos WHERE id = ?", (produto_id,))
conn.commit()
conn.close

print("Produto deletado")
# Out:
# Produto deletado

# %% [markdown]
# ##U3_A2

# %%
import pandas as pd

#Criando uma lista de valores
exemplo1 =[10,20,30,40,50]
print(type(exemplo1))
# Out:
# <class 'list'>

# %%
#criando uma series a partir da lista
series1 = pd.Series(data=exemplo1)

#exibindo a series
print(type(series1))
# Out:
# <class 'pandas.core.series.Series'>

# %%
print(series1)
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# 4    50
# dtype: int64

# %%
import pandas as pd

data = {'A':100, 'B':200, 'C':300, 'D':400, 'E':500}
series2 = pd.Series(data)
print(series2)
# Out:
# A    100
# B    200
# C    300
# D    400
# E    500
# dtype: int64

# %%
#metodos prontos da series
print("Média:", series2.mean())
print("Soma:", series2.sum())
print("Máximo:", series2.max())
print("Mínimo:", series2.min())
# Out:
# Média: 300.0
# Soma: 1500
# Máximo: 500
# Mínimo: 100

# %%
import pandas as pd
url = "https://www.fdic.gov/bank-failures/failed-bank-list"
dfs = pd.read_html(url)

print(type(dfs))
print(len(dfs))
# Out:
# <class 'list'>
# 1

# %%
df_bancos = dfs[0]
print("Dimensões (linhas, colunas): ", df_bancos.shape)
print("\nTipos de cada coluna: ")
print(df_bancos.dtypes)
df_bancos.head()
# Out:
# Dimensões (linhas, colunas):  (25, 7)
#
# Tipos de cada coluna:
# Bank Name                object
# City                     object
# State                    object
# Cert                      int64
# Acquiring Institution    object
# Closing Date             object
# Fund  Sort ascending      int64
# dtype: object
#                                        Bank Name          City         State  \
# 0                    Tioga-Franklin Savings Bank  Philadelphia  Pennsylvania
# 1                            Small Business Bank        Lenexa        Kansas
# 2  Kentland Federal Savings and Loan Association      Kentland       Indiana
# 3        Community Bank and Trust - West Georgia      LaGrange       Georgia
# 4              Metropolitan Capital Bank & Trust       Chicago      Illinois
#
#     Cert                              Acquiring Institution      Closing Date  \
# 0  33802  Second Federal Savings and Loan Association of...   August 21, 2026
# ...

# %%
import pandas as pd
#criar um dicionario com nomes e idades
dados={
    'Nome':['João', 'Maria', 'Pedro', 'Ana'],
    'Idade':[25, 30, 35, 28]
}

#criar uma serie a partir do dicionario
serie_idades = pd.Series(dados['Idade'], index=dados['Nome'])

#exibir a serie
print("serie de idades")
print(serie_idades)

#calcular a média das idades
media_idades = serie_idades.mean()
print("\nMédia de idades:", media_idades)
# Out:
# serie de idades
# João     25
# Maria    30
# Pedro    35
# Ana      28
# dtype: int64
#
# Média de idades: 29.5

# %% [markdown]
# ##U3_A3

# %%
import pandas as pd


# Criando um DataFrame com 5 linhas de dados

data = {

'nome': ['Produto A', 'Produto B', 'Produto C', 'Produto A', 'Produto E'],

'quantidade de itens comprados': [3, 1, 4, 3, 2],

'tipo de item': ['Eletrônico', 'Vestuário', 'Alimento', 'Eletrônico', 'Alimento'],

'receita total': [120, 80, 60, 120, 90]

}

df = pd.DataFrame(data)


# Duplicando uma linha

df.drop_duplicates(keep='last', inplace=True)


# Calculando a coluna 'preço do item'

df['preço do item'] = df['receita total'] / df['quantidade de itens comprados']


# Selecionando preço do item acima de 50 reais

itens_acima_de_50 = df[df['preço do item'] > 50]


print("Itens acima de 50 reais:")
print(itens_acima_de_50)

#resultado
# Out:
# Itens acima de 50 reais:
#         nome  quantidade de itens comprados tipo de item  receita total  \
# 1  Produto B                              1    Vestuário             80
#
#    preço do item
# 1           80.0

# %% [markdown]
# ##U3_A4

# %%
import matplotlib.pyplot as plt
import random

dados1 = random.sample(range(100), k=20)
dados2 = random.sample(range(100), k=20)

plt.plot(dados1, dados2)

# %%
import pandas as dp
dados={
    'Produto':['A','B','C','D','E'],
    'vendas':[100,200,150,300,250]
}
df = pd.DataFrame(dados)
df.plot(x='Produto',y='vendas', kind='bar')
df.plot(x='Produto',y='vendas', kind='pie')
df.plot(x='Produto',y='vendas', kind='line')
# Out:
# <Axes: xlabel='Produto'>

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.set(style="whitegrid")
df_tips = sns.load_dataset("tips")

fig, ax = plt.subplots(1, 3, figsize=(15, 5))

sns.barplot(data=df_tips, x='sex', y='total_bill', ax=ax[0])
sns.barplot(data=df_tips, x='sex', y='total_bill', ax=ax[1], estimator=sum)
sns.barplot(data=df_tips, x='sex', y='total_bill', ax=ax[2], estimator=len)
# Out:
# <Axes: xlabel='sex', ylabel='total_bill'>

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.set(style="whitegrid")
df = sns.load_dataset("tips")

plt.figure(figsize=(8,5))
sns.barplot(x='time', y='total_bill', data=df, estimator=sum, ci=None, palette="Set2")
plt.xlabel('Período(Time)')
plt.ylabel('Total da Conta')
plt.title('Total da Conta por Período')
plt.show()
# Out:
# /tmp/ipykernel_776/4087242494.py:8: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(x='time', y='total_bill', data=df, estimator=sum, ci=None, palette="Set2")
# /tmp/ipykernel_776/4087242494.py:8: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='time', y='total_bill', data=df, estimator=sum, ci=None, palette="Set2")
