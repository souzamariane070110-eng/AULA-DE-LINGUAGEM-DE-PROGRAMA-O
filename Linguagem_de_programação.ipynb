# %% [markdown]
# <a href="https://colab.research.google.com/github/souzamariane070110-eng/AULA-DE-LINGUAGEM-DE-PROGRAMA-O/blob/main/Linguagem_de_programa%C3%A7%C3%A3o.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##U1_A1

# %%
##Nosso primeiro programa

# %%
print("Hello word")
# Out:
# Hello word

# %%
##2 criando variaveis de tipos diferentes
x = 10
nome = 'Anderson'
nota = 8.75
fez_inscricao = True

# %%
print(x)
print(nome)
print(nota)
print(fez_inscricao)
# Out:
# 10
# Anderson
# 8.75
# True

# %%
print(type(x))
print(type(nome))
print(type(nota))
print(type(fez_inscricao))
# Out:
# <class 'int'>
# <class 'str'>
# <class 'float'>
# <class 'bool'>

# %%
nome = input("digite seu nome:")
# Out:
# digite seu nome:Mariane

# %%
print(f"Olá {nome}, bem vindo à disciplina de programação")
# Out:
# Olá Mariane, bem vindo à disciplina de programação

# %%
Nota_1 = int(input("Digite a nota "))
Nota_2 = int(input("Digite a nota "))
Nota_3 = int(input("Digite a nota "))
Nota_4 = int(input("Digite a nota "))
# Out:
# Digite a nota 1
# Digite a nota 2
# Digite a nota 3
# Digite a nota 4

# %%
media = (Nota_1+Nota_2+Nota_3+Nota_4)/4

# %%
print(media)
# Out:
# 2.5

# %%
if media >= 6:
  situação = "Aprovado"
else:
  situação = "Reprovado"

# %%
print(situação)
# Out:
# Reprovado
